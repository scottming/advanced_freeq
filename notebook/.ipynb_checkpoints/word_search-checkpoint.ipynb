# %%
import os
import re
import pandas as pd

# %%
with open('../dictionary/En-Ch_CollinsCOBUILD.txt') as myfile:
    col_data = myfile.read()

# %%
freq_data = pd.read_csv('tst.csv')

# %%
def find_col_mean(dic_data, freq_data):

    p = re.compile(r'\n\n\n\n')
    d = p.split(dic_data) # apply words
    df_dic = pd.DataFrame(d, columns=['Meaning'])
    df_dic['Word'] = df_dic.Meaning.str.extract('(★☆☆\s\s\s.*)\n', expand=False)  # extract the words line

    df_dic = df_dic.loc[:, ['Word', 'Meaning']]
    f = lambda x: str(x)[6:]
    df_dic['Word'] = df_dic.Word.apply(f)  # deep extract

    mean_data = pd.merge(df_dic, freq_data, on='Word').sort_values(
                        ['Freq', 'Word'], ascending=False)
    lst = list(mean_data.Meaning.values)
    return lst

# %%
with open('../dictionary/En-Ch_Oxford_Advanced_Leaners_Dictionary.txt') as myfile1:
    oxf_data = myfile1.read()

# %%
def find_oxf_mean(dic_data, freq_data):

    p = re.compile(r'\n\n\n')
    d = p.split(dic_data) # apply words
    df_dic = pd.DataFrame(d, columns=['Meaning'])
    df_dic['Word'] = df_dic.Meaning.str.extract('(★☆☆\s\s\s.*)\n', expand=False)  # extract the words line

    df_dic = df_dic.loc[:, ['Word', 'Meaning']]
    f = lambda x: str(x)[6:] 
    df_dic['Word'] = df_dic.Word.apply(f) # deep extract

    mean_data = pd.merge(df_dic, freq_data, on='Word').sort_values(
                        ['Freq', 'Word'], ascending=False)
    return mean_data
    lst = list(mean_data.Meaning.values)
    return lst

# %%
len(freq_data)
# Out:
# 1407

# %%
find_oxf_mean_data(oxf_data, freq_data)
# Out:
#               Word                                            Meaning  Freq
# 959          datum  ————————————\n★☆☆   datum\ndatum / ˈdeitəm / n...   618
# 259           plot  ————————————\n★☆☆   plot\nplot / plɔt; ŋæmə pl...   531
# 1269           are  ————————————\n★☆☆   are\nare¹ / ə(r); strong f...   383
# 438          scale  ————————————\n★☆☆   scale\nscale / skeil / nou...   326
# 714       variable  ————————————\n★☆☆   variable\nvari·able / ˈveə...   242
# 44          legend  ————————————\n★☆☆   legend\nle·gend / ˈledʒənd...   210
# 93             map  ————————————\n★☆☆   map\nmap / mæp / noun   a ...   167
# 598          theme  ————————————\n★☆☆   theme\ntheme / θi:m / noun...   163
# 1185      function  ————————————\n★☆☆   function\nfunc·tion / ˈfʌŋ...   149
# 189           axis  ————————————\n★☆☆   axis\naxis / ˈæksis / noun...   148
# 41           layer  ————————————\n★☆☆   layer\nlayer / ˈleiə(r); ˈ...   143
# 817      aesthetic  ————————————\n★☆☆   aesthetic\naes·thet·ic (NA...   143
# 36           label  ————————————\n★☆☆   label\nlabel / ˈleibl / no...   133
# 1220       graphic  ————————————\n★☆☆   graphic\ngraph·ic / ˈɡræfi...   131
# 1128         facet  ————————————\n★☆☆   facet\nfacet / ˈfæsit / no...   127
# 1175         frame  ————————————\n★☆☆   frame\nframe / freim / nou...   123
# 1053       element  ————————————\n★☆☆   element\nelem·ent / ˈelimə...   105
# 990        diamond  ﻿————————————\n★☆☆   diamond\ndia·mond / ˈdaiə...    99
# 217        package  ————————————\n★☆☆   package\npack·age / ˈpækid...    95
# 922     coordinate  ————————————\n★☆☆   coordinate\nco·ord·in·ate ...    90
# 597           text  ————————————\n★☆☆   text\ntext / tekst / noun1...    89
# 963        default  ————————————\n★☆☆   default\nde·fault / diˈfɔ:...    86
# 1004       display  ————————————\n★☆☆   display\ndis·play / diˈspl...    85
# 1270      argument  ————————————\n★☆☆   argument\nar·gu·ment / ˈɑ:...    85
# 1100      exercise  ————————————\n★☆☆   exercise\nex·er·cise / ˈek...    82
# 567        summary  ————————————\n★☆☆   summary\nsum·mary / ˈsʌmər...    76
# 868      component  ————————————\n★☆☆   component\ncom·pon·ent / k...    74
# 453           sect  ————————————\n★☆☆   sect\nsect / sekt / noun  ...    71
# 1224          grid  ————————————\n★☆☆   grid\ngrid / ɡrid / noun1....    70
# 911     continuous  ————————————\n★☆☆   continuous\ncon·tinu·ous /...    70
# ...            ...                                                ...   ...
# 187          aware  ————————————\n★☆☆   aware\naware / əˈweə(r); ŋ...     1
# 141         august  ————————————\n★☆☆   august\nau·gust / ɔ:ˈɡʌst ...     1
# 138     attractive  ————————————\n★☆☆   attractive\nat·tract·ive /...     1
# 76          atomic  ————————————\n★☆☆   atomic\natom·ic / əˈtɔmik;...     1
# 75      asymmetric  ————————————\n★☆☆   asymmetric\nasym·met·ric /...     1
# 71      assignment  ————————————\n★☆☆   assignment\nas·sign·ment /...     1
# 68          assess  ————————————\n★☆☆   assess\nas·sess / əˈses / ...     1
# 67       assertion  ————————————\n★☆☆   assertion\nas·ser·tion / ə...     1
# 66        assemble  ————————————\n★☆☆   assemble\nas·sem·ble / əˈs...     1
# 15        artifact  ————————————\n★☆☆   artifact\nar·ti·fact (espe...     1
# 11     arrangement  ————————————\n★☆☆   arrangement\nar·range·ment...     1
# 9            arise  ————————————\n★☆☆   arise\narise / əˈraiz / ve...     1
# 1268           arc  ————————————\n★☆☆   arc\narc / ɑ:k; ŋæmə ɑ:rk ...     1
# 1263         apple  ————————————\n★☆☆   apple\napple / ˈæpl / noun...     1
# 1208          ante  ————————————\n★☆☆   ante\nante / ˈænti / noun ...     1
# 1155         angry  ————————————\n★☆☆   angry\nangry / ˈæŋɡri / ad...     1
# 1153       analyze  ————————————\n★☆☆   analyze\nana·lyze (NAmE) =...     1
# 1152      analogue  ————————————\n★☆☆   analogue\nana·logue (BrE) ...     1
# 1151     analogous  ————————————\n★☆☆   analogous\nanalo·gous / əˈ...     1
# 1047     ambitious  ————————————\n★☆☆   ambitious\nam·bi·tious / æ...     1
# 1046         amaze  ————————————\n★☆☆   amaze\namaze / əˈmeiz / ve...     1
# 1045    altogether  ————————————\n★☆☆   altogether\nal·together / ...     1
# 1043  alphabetical  ————————————\n★☆☆   alphabetical\nal·pha·bet·i...     1
# 887            aim  ————————————\n★☆☆   aim\naim / eim / noun1. əɔ...     1
# 682     adaptation  ————————————\n★☆☆   adaptation\nadap·ta·tion /...     1
# 676     accumulate  ————————————\n★☆☆   accumulate\nac·cu·mu·late ...     1
# 675        account  ————————————\n★☆☆   account\nac·count / əˈkaun...     1
# 674      accompany  ————————————\n★☆☆   accompany\nac·com·pany / ə...     1
# 6       accentuate  ————————————\n★☆☆   accentuate\nac·cen·tu·ate ...     1
# 4     acceleration  ————————————\n★☆☆   acceleration\nac·cel·er·at...     1
#
# [1342 rows x 3 columns]

# %%
def find

# %%
lst = find_mean_data(dic_data, freq_data)

# %%
freq_data.shape

# %%
len(lst)

# %%
lst[:100]

# %%
freq_data = pd.read_csv('../test_bookfile/')

# %%
data[3000:20000]
